# %%
import pandas as pd

sick2 = pd.read_csv("/home/claudio/Documents/nli-images/nli-images/datasets/SICK/SICK2/SICK2_annotated.tsv", sep="\t")
flickr = pd.read_csv("/home/claudio/Documents/nli-images/flickr8k-text/Flickr8k_text (1)/Flickr8k.token.txt", sep="\t", header=None, names=["jpg", "caption"])

sentences_A = []
for index, row in sick2.iterrows():
    joined_A = "".join([x for x in sick2.sentence_A_original[index].lower() if x.isalpha()])
    sentences_A.append(joined_A)
sick2["sent_A"] = pd.Series(sentences_A, index=sick2.index)

flickr_joined = []
for index, row in flickr.iterrows():
    flickr_joined.append("".join([x for x in flickr.iloc[index][1].lower() if x.isalpha()]))
flickr["joined"] = pd.Series(flickr_joined, index=flickr.index)

# %%
sick2
# Out:
#       pair_ID   pair_type                                         sentence_A  \
# 0           1  S1S2_intra  A group of kids is playing in a yard and an ol...
# 1           3  S1S2_intra  The young boys are playing outdoors and the ma...
# 2           4  S1S3_intra  The young boys are playing outdoors and the ma...
# 3           9  S1S1_inter  The young boys are playing outdoors and the ma...
# 4          11  S1S3_intra  A brown dog is attacking another animal in fro...
# 5          13  S1S3_intra                 Two dogs are wrestling and hugging
# 6          14  S1S2_inter  A brown dog is attacking another animal in fro...
# 7          15  S1S3_inter  A brown dog is attacking another animal in fro...
# 8          16  S1S2_inter                 Two dogs are wrestling and hugging
# 9          17  S1S3_inter                 Two dogs are wrestling and hugging
# 10         18  S1S1_inter  A brown dog is attacking another animal in fro...
# ...

# %%
flickr
# Out:
#                                jpg  \
# 0      1000268201_693b08cb0e.jpg#0
# 1      1000268201_693b08cb0e.jpg#1
# 2      1000268201_693b08cb0e.jpg#2
# 3      1000268201_693b08cb0e.jpg#3
# 4      1000268201_693b08cb0e.jpg#4
# 5      1001773457_577c3a7d70.jpg#0
# 6      1001773457_577c3a7d70.jpg#1
# 7      1001773457_577c3a7d70.jpg#2
# 8      1001773457_577c3a7d70.jpg#3
# 9      1001773457_577c3a7d70.jpg#4
# 10     1002674143_1b742ab4b8.jpg#0
# 11     1002674143_1b742ab4b8.jpg#1
# 12     1002674143_1b742ab4b8.jpg#2
# 13     1002674143_1b742ab4b8.jpg#3
# 14     1002674143_1b742ab4b8.jpg#4
# 15     1003163366_44323f5815.jpg#0
# 16     1003163366_44323f5815.jpg#1
# 17     1003163366_44323f5815.jpg#2
# 18     1003163366_44323f5815.jpg#3
# 19     1003163366_44323f5815.jpg#4
# 20     1007129816_e794419615.jpg#0
# 21     1007129816_e794419615.jpg#1
# 22     1007129816_e794419615.jpg#2
# 23     1007129816_e794419615.jpg#3
# 24     1007129816_e794419615.jpg#4
# ...

# %%
vsick2 = sick2.merge(flickr, left_on="sent_A", right_on="joined", how="inner")
sick2.query("pair_ID == 549")
# Out:
#      pair_ID   pair_type                                         sentence_A  \
# 300      549  S1S4_inter  The man in a grey t-shirt is sitting on a rock...
#
#     sentence_A_expRule                                         sentence_B  \
# 300            S1_null  Somebody is sitting at the waterfall and looki...
#
#     sentence_B_expRule  relatedness_score entailment_label entailment_AB  \
# 300            S4_null                3.5          NEUTRAL   A_neutral_B
#
#     entailment_BA                                sentence_A_original  \
# 300   B_neutral_A  a man in a grey shirt is sitting on a rock in ...
#
#                       sentence_B_original sentence_A_dataset  \
# 300  A woman sits staring at a waterfall.             FLICKR
#
#     sentence_B_dataset SemEval_set  \
# 300             FLICKR        TEST
#
#                                                 sent_A
# 300  amaninagreyshirtissittingonarockinfrontofawate...

# %%
sick = pd.read_csv("/home/claudio/Documents/nli-images/nli-images/datasets/SICK/SICK/SICK_annotated.txt", sep="\t")

vsick2.query("pair_ID == 7831")
# Out:
#      pair_ID   pair_type                           sentence_A  \
# 764     7831  S1S2_intra  The brown dog is jumping in the air
# 765     7831  S1S2_intra  The brown dog is jumping in the air
#
#     sentence_A_expRule                              sentence_B  \
# 764            S1_null  The brown animal is jumping in the air
# 765            S1_null  The brown animal is jumping in the air
#
#     sentence_B_expRule  relatedness_score entailment_label entailment_AB  \
# 764             S2_lex                4.4       ENTAILMENT   A_entails_B
# 765             S2_lex                4.4       ENTAILMENT   A_entails_B
#
#     entailment_BA           sentence_A_original           sentence_B_original  \
# 764   B_neutral_A  a brown dog jumps in the air  a brown dog jumps in the air
# 765   B_neutral_A  a brown dog jumps in the air  a brown dog jumps in the air
#
#     sentence_A_dataset sentence_B_dataset SemEval_set                  sent_A  \
# ...

# %%
vsick2.query("pair_ID == 7835")
# Out:
#      pair_ID   pair_type                           sentence_A  \
# 768     7835  S1S2_inter  The brown dog is jumping in the air
# 769     7835  S1S2_inter  The brown dog is jumping in the air
#
#     sentence_A_expRule                   sentence_B sentence_B_expRule  \
# 768            S1_null  A dog is jumping in the air            S2_null
# 769            S1_null  A dog is jumping in the air            S2_null
#
#      relatedness_score entailment_label entailment_AB entailment_BA  \
# 768                4.4       ENTAILMENT   A_entails_B   B_neutral_A
# 769                4.4       ENTAILMENT   A_entails_B   B_neutral_A
#
#               sentence_A_original             sentence_B_original  \
# 768  a brown dog jumps in the air  a brown dog jumping in the air
# 769  a brown dog jumps in the air  a brown dog jumping in the air
#
#     sentence_A_dataset sentence_B_dataset SemEval_set                  sent_A  \
# ...

# %%
vsick2.query("pair_ID == 7831").iloc[0] == vsick2.query("pair_ID == 7835").iloc[0]
# Out:
# pair_ID                False
# pair_type              False
# sentence_A              True
# sentence_A_expRule      True
# sentence_B             False
# sentence_B_expRule     False
# relatedness_score       True
# entailment_label        True
# entailment_AB           True
# entailment_BA           True
# sentence_A_original     True
# sentence_B_original    False
# sentence_A_dataset      True
# sentence_B_dataset      True
# SemEval_set             True
# sent_A                  True
# jpg                     True
# caption                 True
# joined                  True
# dtype: bool
